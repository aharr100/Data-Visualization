# %% [markdown]
# <a href="https://colab.research.google.com/github/aharr100/Data-Visualization/blob/main/Data_Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np #Numpy provides fast mathematical function processing
import pandas as pd #Pandas is used for easy indexing and data collection tools
import matplotlib as mpl #Library for high level data visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#My Data is called Raw Global Deaths so I named "RAW_global_deaths" my dataframe (change the name of yours relative to data)
RAW_global_deaths=pd.read_csv("https://raw.githubusercontent.com/aharr100/Data-Visualization/main/RAW_global_deaths.csv", encoding='latin1')

# %%
#This function previews your data
RAW_global_deaths.head()
# Out:
#   Country/Region Province/State       Lat  ...  11/20/2020  11/21/2020  11/22/2020
# 0    Afghanistan            NaN  33.93911  ...        1661        1675        1687
# 1        Albania            NaN  41.15330  ...         672         685         699
# 2        Algeria            NaN  28.03390  ...        2236        2255        2272
# 3        Andorra            NaN  42.50630  ...          76          76          76
# 4         Angola            NaN -11.20270  ...         334         336         337
#
# [5 rows x 310 columns]

# %%
#Gives a list of column names
RAW_global_deaths.columns.values
# Out:
# array(['Country/Region', 'Province/State', 'Lat', 'Long', '1/22/2020',
#        '1/23/2020', '1/24/2020', '1/25/2020', '1/26/2020', '1/27/2020',
#        '1/28/2020', '1/29/2020', '1/30/2020', '1/31/2020', '2/1/2020',
#        '2/2/2020', '2/3/2020', '2/4/2020', '2/5/2020', '2/6/2020',
#        '2/7/2020', '2/8/2020', '2/9/2020', '2/10/2020', '2/11/2020',
#        '2/12/2020', '2/13/2020', '2/14/2020', '2/15/2020', '2/16/2020',
#        '2/17/2020', '2/18/2020', '2/19/2020', '2/20/2020', '2/21/2020',
#        '2/22/2020', '2/23/2020', '2/24/2020', '2/25/2020', '2/26/2020',
#        '2/27/2020', '2/28/2020', '2/29/2020', '3/1/2020', '3/2/2020',
#        '3/3/2020', '3/4/2020', '3/5/2020', '3/6/2020', '3/7/2020',
#        '3/8/2020', '3/9/2020', '3/10/2020', '3/11/2020', '3/12/2020',
#        '3/13/2020', '3/14/2020', '3/15/2020', '3/16/2020', '3/17/2020',
#        '3/18/2020', '3/19/2020', '3/20/2020', '3/21/2020', '3/22/2020',
# ...

# %%
#Gives size of data you have uploaded
RAW_global_deaths.shape
# Out:
# (269, 310)

# %%
#Presents all of the data
RAW_global_deaths
# Out:
#          Country/Region Province/State  ...  11/21/2020  11/22/2020
# 0           Afghanistan            NaN  ...        1675        1687
# 1               Albania            NaN  ...         685         699
# 2               Algeria            NaN  ...        2255        2272
# 3               Andorra            NaN  ...          76          76
# 4                Angola            NaN  ...         336         337
# ..                  ...            ...  ...         ...         ...
# 264  West Bank and Gaza            NaN  ...         620         636
# 265      Western Sahara            NaN  ...           1           1
# 266               Yemen            NaN  ...         608         608
# 267              Zambia            NaN  ...         356         357
# 268            Zimbabwe            NaN  ...         265         268
#
# [269 rows x 310 columns]

# %%
RAW_global_deaths.plot

# %%
#Rename DataFrame to not overwrite original
#Executive Code
#Pick two columns
RAW_global_deaths2=RAW_global_deaths.plot.line(x='Country/Region', y='10/14/2020')

plt.title('Line Plot')
plt.xlabel('Country/Region')
plt.ylabel('Deaths')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
RAW_global_deaths2=RAW_global_deaths.plot.line(x='Country/Region', y='10/14/2020')
plt.title('Line Plot')
plt.xlabel('Country/Region')
plt.ylabel('Deaths')
plt.rcParams['figure.figsize']={12,4}
plt.show
# Out:
# <function matplotlib.pyplot.show>
